# %%
from pydantic.v1 import BaseModel

from langchain_openai import ChatOpenAI
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)

chat = ChatOpenAI(model_name='gpt-4o-mini', temperature=0.9)
sys = SystemMessage(content="당신은 음악 추천을 해주는 전문 AI입니다.")
msg = HumanMessage(content='1990년대 재즈 5곡만 추천해줘.')

aimsg = chat([sys, msg])
aimsg.content
# Out:
# '1990년대는 재즈의 다양한 스타일과 실험이 시도되었던 시기입니다. 아래는 1990년대에 발표된 재즈 곡 5곡을 추천합니다:\n\n1. **"The Crossing" - Bill Evans** (1996)\n   - 피아니스트 빌 에반스의 섬세한 연주가 돋보이는 곡으로, 그의 독창적인 스타일이 잘 담겨 있습니다.\n\n2. **"In the Mood" - Wynton Marsalis** (1994)\n   - 윈튼 마살리스의 트럼펫 연주로, 클래식 재즈의 요소를 현대적으로 풀어낸 멋진 곡입니다.\n\n3. **"Spiral" - Chick Corea** (1998)\n   - 피아노 거장 치크 코리아의 독창적인 하모니와 리듬이 인상적인 곡으로, 다양한 악기와의 조화가 매력적입니다.\n\n4. **"Tutu" - Miles Davis** (1986)\n   - 비록 1986년에 발표되었지만, 1990년대에도 많은 사랑을 받았던 마일스 데이비스의 곡으로, 재즈 퓨전의 아이콘으로 자리 잡았습니다.\n\n5. **"Watermelon Man" - Herbie Hancock (Live in Montreux)** (1997)\n   - 허비 행콕의 라이브 연주로, 그의 대표곡 중 하나인 "Watermelon Man"을 새로운 해석으로 즐길 수 있습니다.\n\n이 곡들을 통해 1990년대 재즈의 매력을 느껴보시길 바랍니다!'

# %%
# !pip install numexpr
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numexpr in /home/kkimmu/.local/lib/python3.10/site-packages (2.11.0)
# Requirement already satisfied: numpy>=1.23.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from numexpr) (1.26.4)

# %%
# !pip install google-search-results
# !pip install wikipedia
# !pip install faiss-cpu 
# !pip install sentence_transformers 
# !pip install tiktoken
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-search-results in /home/kkimmu/.local/lib/python3.10/site-packages (2.4.2)
# Requirement already satisfied: requests in /home/kkimmu/.local/lib/python3.10/site-packages (from google-search-results) (2.32.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests->google-search-results) (2025.7.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests->google-search-results) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests->google-search-results) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->google-search-results) (3.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wikipedia in /home/kkimmu/.local/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /home/kkimmu/.local/lib/python3.10/site-packages (from wikipedia) (4.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from wikipedia) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2025.7.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.5.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from beautifulsoup4->wikipedia) (4.14.1)
# Requirement already satisfied: soupsieve>1.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from beautifulsoup4->wikipedia) (2.7)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: faiss-cpu in /home/kkimmu/.local/lib/python3.10/site-packages (1.11.0.post1)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /home/kkimmu/.local/lib/python3.10/site-packages (from faiss-cpu) (25.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sentence_transformers in /home/kkimmu/.local/lib/python3.10/site-packages (5.0.0)
# Requirement already satisfied: scipy in /home/kkimmu/.local/lib/python3.10/site-packages (from sentence_transformers) (1.15.3)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from sentence_transformers) (4.53.3)
# Requirement already satisfied: Pillow in /home/kkimmu/.local/lib/python3.10/site-packages (from sentence_transformers) (11.3.0)
# Requirement already satisfied: tqdm in /home/kkimmu/.local/lib/python3.10/site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from sentence_transformers) (2.7.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from sentence_transformers) (4.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from sentence_transformers) (0.33.4)
# Requirement already satisfied: scikit-learn in /home/kkimmu/.local/lib/python3.10/site-packages (from sentence_transformers) (1.7.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.7.0)
# Requirement already satisfied: requests in /home/kkimmu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.4)
# Requirement already satisfied: packaging>=20.9 in /home/kkimmu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (25.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (1.1.5)
# Requirement already satisfied: filelock in /home/kkimmu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (5.4.1)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (9.5.1.17)
# Requirement already satisfied: triton==3.3.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.3.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.6.80)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (0.6.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.6.77)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (1.11.1.6)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.6.85)
# Requirement already satisfied: networkx in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (2.26.2)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch>=1.11.0->sentence_transformers) (3.0.3)
# Requirement already satisfied: sympy>=1.13.3 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (1.14.0)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (12.5.4.2)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/lib/python3/dist-packages (from triton==3.3.1->torch>=1.11.0->sentence_transformers) (59.6.0)
# Requirement already satisfied: numpy>=1.17 in /home/kkimmu/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/kkimmu/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.21.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/kkimmu/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in /home/kkimmu/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (1.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2025.7.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.5.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tiktoken in /home/kkimmu/.local/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: requests>=2.26.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: regex>=2022.1.18 in /home/kkimmu/.local/lib/python3.10/site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.26.0->tiktoken) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2025.7.14)

# %%
# !pip install -U openai langchain langchain-openai langchain-community
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in /home/kkimmu/.local/lib/python3.10/site-packages (1.97.1)
# Requirement already satisfied: langchain in /home/kkimmu/.local/lib/python3.10/site-packages (0.3.26)
# Requirement already satisfied: langchain-openai in /home/kkimmu/.local/lib/python3.10/site-packages (0.3.28)
# Requirement already satisfied: langchain-community in /home/kkimmu/.local/lib/python3.10/site-packages (0.3.27)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from openai) (4.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from openai) (0.10.0)
# Requirement already satisfied: tqdm>4 in /home/kkimmu/.local/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from openai) (0.28.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: sniffio in /home/kkimmu/.local/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from openai) (2.11.7)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/kkimmu/.local/lib/python3.10/site-packages (from openai) (4.14.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langsmith>=0.1.17 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain) (0.4.8)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain) (0.3.70)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: PyYAML>=5.3 in /usr/lib/python3/dist-packages (from langchain) (5.4.1)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: requests<3,>=2 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain) (2.32.4)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-community) (3.12.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/kkimmu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (21.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: httpcore==1.* in /home/kkimmu/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: certifi in /home/kkimmu/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: h11>=0.16 in /home/kkimmu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: packaging>=23.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (25.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/kkimmu/.local/lib/python3.10/site-packages (from langsmith>=0.1.17->langchain) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /home/kkimmu/.local/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: regex>=2022.1.18 in /home/kkimmu/.local/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/lib/python3/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)

# %%
# !pip install -qU langchain-teddynote
# !pip install -U langchain-teddynote
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-teddynote in /home/kkimmu/.local/lib/python3.10/site-packages (0.3.45)
# Requirement already satisfied: anthropic in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (0.58.2)
# Requirement already satisfied: pandas in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (2.3.1)
# Requirement already satisfied: tavily-python in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (0.7.10)
# Requirement already satisfied: olefile in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (0.47)
# Requirement already satisfied: pinecone-client[grpc] in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (6.0.0)
# Requirement already satisfied: kiwipiepy in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (0.21.0)
# Requirement already satisfied: pdf2image in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (1.17.0)
# Requirement already satisfied: openai in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (1.97.1)
# Requirement already satisfied: langgraph in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (0.5.4)
# Requirement already satisfied: langchain in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (0.3.26)
# Requirement already satisfied: pinecone-text in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (0.10.0)
# Requirement already satisfied: feedparser in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (6.0.11)
# Requirement already satisfied: deepl in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (1.22.0)
# Requirement already satisfied: rank_bm25 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-teddynote) (0.2.2)
# Requirement already satisfied: sniffio in /home/kkimmu/.local/lib/python3.10/site-packages (from anthropic->langchain-teddynote) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /home/kkimmu/.local/lib/python3.10/site-packages (from anthropic->langchain-teddynote) (4.14.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from anthropic->langchain-teddynote) (0.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from anthropic->langchain-teddynote) (1.7.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from anthropic->langchain-teddynote) (2.11.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from anthropic->langchain-teddynote) (4.9.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from anthropic->langchain-teddynote) (0.28.1)
# Requirement already satisfied: requests<3,>=2 in /home/kkimmu/.local/lib/python3.10/site-packages (from deepl->langchain-teddynote) (2.32.4)
# Requirement already satisfied: sgmllib3k in /home/kkimmu/.local/lib/python3.10/site-packages (from feedparser->langchain-teddynote) (1.0.0)
# Requirement already satisfied: tqdm in /home/kkimmu/.local/lib/python3.10/site-packages (from kiwipiepy->langchain-teddynote) (4.67.1)
# Requirement already satisfied: kiwipiepy_model<0.22,>=0.21 in /home/kkimmu/.local/lib/python3.10/site-packages (from kiwipiepy->langchain-teddynote) (0.21.0)
# Requirement already satisfied: numpy in /home/kkimmu/.local/lib/python3.10/site-packages (from kiwipiepy->langchain-teddynote) (1.26.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain->langchain-teddynote) (4.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain->langchain-teddynote) (2.0.41)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain->langchain-teddynote) (0.3.70)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain->langchain-teddynote) (0.3.8)
# Requirement already satisfied: PyYAML>=5.3 in /usr/lib/python3/dist-packages (from langchain->langchain-teddynote) (5.4.1)
# Requirement already satisfied: langsmith>=0.1.17 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain->langchain-teddynote) (0.4.8)
# Requirement already satisfied: langgraph-prebuilt<0.6.0,>=0.5.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langgraph->langchain-teddynote) (0.5.2)
# Requirement already satisfied: xxhash>=3.5.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langgraph->langchain-teddynote) (3.5.0)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in /home/kkimmu/.local/lib/python3.10/site-packages (from langgraph->langchain-teddynote) (0.1.74)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langgraph->langchain-teddynote) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from pandas->langchain-teddynote) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from pandas->langchain-teddynote) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/kkimmu/.local/lib/python3.10/site-packages (from pandas->langchain-teddynote) (2025.2)
# Requirement already satisfied: pillow in /home/kkimmu/.local/lib/python3.10/site-packages (from pdf2image->langchain-teddynote) (11.3.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /home/kkimmu/.local/lib/python3.10/site-packages (from pinecone-client[grpc]->langchain-teddynote) (0.0.7)
# Requirement already satisfied: urllib3>=1.26.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from pinecone-client[grpc]->langchain-teddynote) (2.5.0)
# Requirement already satisfied: certifi>=2019.11.17 in /home/kkimmu/.local/lib/python3.10/site-packages (from pinecone-client[grpc]->langchain-teddynote) (2025.7.14)
# Requirement already satisfied: lz4>=3.1.3 in /home/kkimmu/.local/lib/python3.10/site-packages (from pinecone-client[grpc]->langchain-teddynote) (4.4.4)
# Requirement already satisfied: protobuf<6.0,>=5.29 in /home/kkimmu/.local/lib/python3.10/site-packages (from pinecone-client[grpc]->langchain-teddynote) (5.29.5)
# Requirement already satisfied: grpcio>=1.44.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from pinecone-client[grpc]->langchain-teddynote) (1.73.1)
# Requirement already satisfied: googleapis-common-protos>=1.66.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from pinecone-client[grpc]->langchain-teddynote) (1.70.0)
# Requirement already satisfied: protoc-gen-openapiv2<0.0.2,>=0.0.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from pinecone-client[grpc]->langchain-teddynote) (0.0.1)
# Requirement already satisfied: nltk<4.0.0,>=3.9.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from pinecone-text->langchain-teddynote) (3.9.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from pinecone-text->langchain-teddynote) (1.1.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.25.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from pinecone-text->langchain-teddynote) (2.32.4.20250611)
# Requirement already satisfied: mmh3<5.0.0,>=4.1.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from pinecone-text->langchain-teddynote) (4.1.0)
# Requirement already satisfied: tiktoken>=0.5.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from tavily-python->langchain-teddynote) (0.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->anthropic->langchain-teddynote) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic->langchain-teddynote) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /home/kkimmu/.local/lib/python3.10/site-packages (from httpx<1,>=0.25.0->anthropic->langchain-teddynote) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/kkimmu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic->langchain-teddynote) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain->langchain-teddynote) (1.33)
# Requirement already satisfied: packaging>=23.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain->langchain-teddynote) (25.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain->langchain-teddynote) (9.1.2)
# Requirement already satisfied: ormsgpack>=1.10.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph->langchain-teddynote) (1.10.0)
# Requirement already satisfied: orjson>=3.10.1 in /home/kkimmu/.local/lib/python3.10/site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph->langchain-teddynote) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langsmith>=0.1.17->langchain->langchain-teddynote) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from langsmith>=0.1.17->langchain->langchain-teddynote) (0.23.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/kkimmu/.local/lib/python3.10/site-packages (from nltk<4.0.0,>=3.9.1->pinecone-text->langchain-teddynote) (2024.11.6)
# Requirement already satisfied: joblib in /home/kkimmu/.local/lib/python3.10/site-packages (from nltk<4.0.0,>=3.9.1->pinecone-text->langchain-teddynote) (1.5.1)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk<4.0.0,>=3.9.1->pinecone-text->langchain-teddynote) (8.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic->langchain-teddynote) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/kkimmu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic->langchain-teddynote) (0.4.1)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/kkimmu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic->langchain-teddynote) (2.33.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->langchain-teddynote) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kkimmu/.local/lib/python3.10/site-packages (from requests<3,>=2->deepl->langchain-teddynote) (3.4.2)
# Requirement already satisfied: greenlet>=1 in /home/kkimmu/.local/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain->langchain-teddynote) (3.2.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/lib/python3/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain->langchain-teddynote) (2.0)
