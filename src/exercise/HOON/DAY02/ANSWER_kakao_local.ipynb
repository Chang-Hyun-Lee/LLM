# %%
# !pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in /home/ubuntu/.local/lib/python3.10/site-packages (1.97.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (4.9.0)
# Requirement already satisfied: sniffio in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (0.10.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (0.28.1)
# Requirement already satisfied: tqdm>4 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (4.14.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (2.11.7)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: certifi in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/ubuntu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)

# %%
import os

os.environ["OPENAI_DEFAULT_MODEL"] = "gpt-4o-mini"

# %%
import requests
import os

searching = '판교동 레스토랑'
kakao_api_key = os.getenv("KAKAO_API_KEY")
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
headers = {
    "Authorization": f"KakaoAK {kakao_api_key}"
}
places = requests.get(url, headers = headers).json()
places
# Out:
# {'documents': [{'address_name': '경기 성남시 분당구 판교동 614',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '21484277',
#    'phone': '031-8016-1865',
#    'place_name': '뚜에이오',
#    'place_url': 'http://place.map.kakao.com/21484277',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 24-2',
#    'x': '127.08878251993',
#    'y': '37.3913068226745'},
#   {'address_name': '경기 성남시 분당구 판교동 614-6',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '14589499',
#    'phone': '',
#    'place_name': '라비떼',
#    'place_url': 'http://place.map.kakao.com/14589499',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 16',
#    'x': '127.08955522531403',
#    'y': '37.39155131811151'},
#   {'address_name': '경기 성남시 분당구 판교동 599',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '16065056',
#    'phone': '031-8016-6262',
#    'place_name': '샤슬릭',
#    'place_url': 'http://place.map.kakao.com/16065056',
#    'road_address_name': '경기 성남시 분당구 판교공원로2길 45',
#    'x': '127.09300276802902',
#    'y': '37.38964029121598'},
#   {'address_name': '경기 성남시 분당구 판교동 617-1',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '27300858',
#    'phone': '0502-5551-6969',
#    'place_name': '라스토리아1001',
#    'place_url': 'http://place.map.kakao.com/27300858',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 24',
#    'x': '127.088863533106',
#    'y': '37.3910580796215'},
#   {'address_name': '경기 성남시 분당구 판교동 600-5',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '708092398',
#    'phone': '010-3005-9541',
#    'place_name': '오스테리아 워모잡',
#    'place_url': 'http://place.map.kakao.com/708092398',
#    'road_address_name': '경기 성남시 분당구 판교공원로2길 40-1',
#    'x': '127.093826013936',
#    'y': '37.3896666715851'},
#   {'address_name': '경기 성남시 분당구 판교동 618-7',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 멕시칸,브라질',
#    'distance': '',
#    'id': '442176392',
#    'phone': '031-703-0255',
#    'place_name': '갓잇 서판교점',
#    'place_url': 'http://place.map.kakao.com/442176392',
#    'road_address_name': '경기 성남시 분당구 판교공원로5길 24',
#    'x': '127.089829598053',
#    'y': '37.3905725995806'},
#   {'address_name': '경기 성남시 분당구 판교동 610',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '2092406855',
#    'phone': '031-701-0345',
#    'place_name': '피제리아 비니스',
#    'place_url': 'http://place.map.kakao.com/2092406855',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 70',
#    'x': '127.091160140249',
#    'y': '37.3908085502984'},
#   {'address_name': '경기 성남시 분당구 판교동 497',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자 > 도미노피자',
#    'distance': '',
#    'id': '18154958',
#    'phone': '031-8017-9096',
#    'place_name': '도미노피자 판교점',
#    'place_url': 'http://place.map.kakao.com/18154958',
#    'road_address_name': '경기 성남시 분당구 서판교로 160',
#    'x': '127.09485899977564',
#    'y': '37.400209605227566'},
#   {'address_name': '경기 성남시 분당구 판교동 602-2',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '1793834083',
#    'phone': '031-781-0122',
#    'place_name': '에이치이에이',
#    'place_url': 'http://place.map.kakao.com/1793834083',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 67',
#    'x': '127.091385646215',
#    'y': '37.3905245541454'},
#   {'address_name': '경기 성남시 분당구 판교동 616-6',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자',
#    'distance': '',
#    'id': '1363058678',
#    'phone': '031-709-7499',
#    'place_name': '피제리아 살레르노 서판교점',
#    'place_url': 'http://place.map.kakao.com/1363058678',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 35',
#    'x': '127.09016326928636',
#    'y': '37.39102555996761'},
#   {'address_name': '경기 성남시 분당구 판교동 567-2',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '1813415551',
#    'phone': '031-8016-0168',
#    'place_name': '플랩잭팬트리 본점',
#    'place_url': 'http://place.map.kakao.com/1813415551',
#    'road_address_name': '경기 성남시 분당구 서판교로44번길 17-11',
#    'x': '127.099584320006',
#    'y': '37.3916234885259'},
#   {'address_name': '경기 성남시 분당구 판교동 512',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자 > 파파존스',
#    'distance': '',
#    'id': '27334535',
#    'phone': '031-709-9492',
#    'place_name': '파파존스 판교점',
#    'place_url': 'http://place.map.kakao.com/27334535',
#    'road_address_name': '경기 성남시 분당구 서판교로 154',
#    'x': '127.09521543438433',
#    'y': '37.39985071235571'},
#   {'address_name': '경기 성남시 분당구 판교동 598-3',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '1828152491',
#    'phone': '0502-5551-9817',
#    'place_name': '마레아',
#    'place_url': 'http://place.map.kakao.com/1828152491',
#    'road_address_name': '경기 성남시 분당구 판교공원로2길 49',
#    'x': '127.09253312812879',
#    'y': '37.38973977213277'},
#   {'address_name': '경기 성남시 분당구 판교동 602-1',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '817384546',
#    'phone': '031-778-6463',
#    'place_name': '칠리로29 판교점',
#    'place_url': 'http://place.map.kakao.com/817384546',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 69',
#    'x': '127.09122079999591',
#    'y': '37.39054450391926'},
#   {'address_name': '경기 성남시 분당구 판교동 614-9',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '1992463433',
#    'phone': '',
#    'place_name': '일로이 키친',
#    'place_url': 'http://place.map.kakao.com/1992463433',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 10',
#    'x': '127.09016037466169',
#    'y': '37.3914373294357'}],
#  'meta': {'is_end': False,
#   'pageable_count': 45,
#   'same_name': {'keyword': '레스토랑',
#    'region': [],
#    'selected_region': '경기 성남시 분당구 판교동'},
#   'total_count': 263}}

# %%
question = "강남에 있는 일식집을 두세개 추천해줘."

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": """다음 질문에서 지명 하나와 가장 중요한 키워드 하나를 추출해서 하나로 붙여줘.
원하는 형식:
<place>:<keyword>
"""
    },
    {
      "role": "user",
      "content": question
    }
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 강남:일식집

# %%
array = response.choices[0].message.content.split(":")
location = array[0]
keyword = array[1]

location, keyword
# Out:
# ('강남', '일식집')

# %%
import requests

searching = f'{location} {keyword}'
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
headers = {
    "Authorization": f"KakaoAK {kakao_api_key}"
}
places = requests.get(url, headers = headers).json()
places
# Out:
# {'documents': [{'address_name': '서울 강남구 신사동 647-22',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 돈까스,우동',
#    'distance': '',
#    'id': '1480354584',
#    'phone': '02-547-3903',
#    'place_name': '카츠바이콘반',
#    'place_url': 'http://place.map.kakao.com/1480354584',
#    'road_address_name': '서울 강남구 선릉로153길 36',
#    'x': '127.03646084537056',
#    'y': '37.52479790585425'},
#   {'address_name': '서울 강남구 역삼동 822-4',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 초밥,롤',
#    'distance': '',
#    'id': '13575898',
#    'phone': '02-2051-1477',
#    'place_name': '갓덴스시 강남점',
#    'place_url': 'http://place.map.kakao.com/13575898',
#    'road_address_name': '서울 강남구 테헤란로 109',
#    'x': '127.029090699483',
#    'y': '37.498777145173'},
#   {'address_name': '서울 강남구 역삼동 601-29',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 돈까스,우동',
#    'distance': '',
#    'id': '850873071',
#    'phone': '0507-1316-0924',
#    'place_name': '정돈 강남점',
#    'place_url': 'http://place.map.kakao.com/850873071',
#    'road_address_name': '서울 강남구 강남대로110길 19-1',
#    'x': '127.02638857680932',
#    'y': '37.503909008238786'},
#   {'address_name': '서울 강남구 논현동 5-13',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 초밥,롤',
#    'distance': '',
#    'id': '10201006',
#    'phone': '02-542-5235',
#    'place_name': '김수사',
#    'place_url': 'http://place.map.kakao.com/10201006',
#    'road_address_name': '서울 강남구 도산대로12길 7',
#    'x': '127.02375201725121',
#    'y': '37.5172300181637'},
#   {'address_name': '서울 강남구 논현동 11-1',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 돈까스,우동',
#    'distance': '',
#    'id': '901836680',
#    'phone': '02-515-3622',
#    'place_name': '현우동',
#    'place_url': 'http://place.map.kakao.com/901836680',
#    'road_address_name': '서울 강남구 논현로149길 53',
#    'x': '127.024288113104',
#    'y': '37.517007361287'},
#   {'address_name': '서울 강남구 신사동 519-4',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 돈까스,우동',
#    'distance': '',
#    'id': '1402068738',
#    'phone': '02-549-0924',
#    'place_name': '정돈 신사점',
#    'place_url': 'http://place.map.kakao.com/1402068738',
#    'road_address_name': '서울 강남구 강남대로160길 28',
#    'x': '127.0210447372859',
#    'y': '37.51975063774249'},
#   {'address_name': '서울 강남구 역삼동 826-26',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 참치회',
#    'distance': '',
#    'id': '13119179',
#    'phone': '02-538-2979',
#    'place_name': '큰물참치 강남점',
#    'place_url': 'http://place.map.kakao.com/13119179',
#    'road_address_name': '서울 강남구 테헤란로2길 27',
#    'x': '127.02969820710979',
#    'y': '37.49649294264577'},
#   {'address_name': '서울 강남구 역삼동 831-27',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 참치회',
#    'distance': '',
#    'id': '1614493196',
#    'phone': '02-538-0220',
#    'place_name': '참치공방 강남점',
#    'place_url': 'http://place.map.kakao.com/1614493196',
#    'road_address_name': '서울 강남구 강남대로78길 18',
#    'x': '127.03087594291',
#    'y': '37.4950285047535'},
#   {'address_name': '서울 강남구 신사동 537-2',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 초밥,롤',
#    'distance': '',
#    'id': '18948155',
#    'phone': '02-3444-4988',
#    'place_name': '은행골 신사점',
#    'place_url': 'http://place.map.kakao.com/18948155',
#    'road_address_name': '서울 강남구 강남대로152길 42',
#    'x': '127.02275909671525',
#    'y': '37.51800237359273'},
#   {'address_name': '서울 강남구 논현동 275-3',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 돈까스,우동',
#    'distance': '',
#    'id': '16875542',
#    'phone': '02-511-6247',
#    'place_name': '가나돈까스의집',
#    'place_url': 'http://place.map.kakao.com/16875542',
#    'road_address_name': '서울 강남구 언주로 608',
#    'x': '127.03779952558008',
#    'y': '37.50986785826047'},
#   {'address_name': '서울 강남구 대치동 895-1',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식',
#    'distance': '',
#    'id': '913979606',
#    'phone': '02-501-3328',
#    'place_name': '참치공방 선릉점',
#    'place_url': 'http://place.map.kakao.com/913979606',
#    'road_address_name': '서울 강남구 삼성로85길 39',
#    'x': '127.054272503282',
#    'y': '37.5042247512771'},
#   {'address_name': '서울 강남구 대치동 894',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 초밥,롤',
#    'distance': '',
#    'id': '977331811',
#    'phone': '02-567-8200',
#    'place_name': '스시소라 대치점',
#    'place_url': 'http://place.map.kakao.com/977331811',
#    'road_address_name': '서울 강남구 삼성로85길 33',
#    'x': '127.054819929805',
#    'y': '37.5042821628439'},
#   {'address_name': '서울 강남구 역삼동 677-5',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 초밥,롤',
#    'distance': '',
#    'id': '887468501',
#    'phone': '02-558-7771',
#    'place_name': '츄라우미 역삼본점',
#    'place_url': 'http://place.map.kakao.com/887468501',
#    'road_address_name': '서울 강남구 언주로93길 21',
#    'x': '127.040325028884',
#    'y': '37.5033365384302'},
#   {'address_name': '서울 강남구 신사동 525-15',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식',
#    'distance': '',
#    'id': '476435584',
#    'phone': '02-545-7940',
#    'place_name': '온기정',
#    'place_url': 'http://place.map.kakao.com/476435584',
#    'road_address_name': '서울 강남구 압구정로4길 13-9',
#    'x': '127.020878002399',
#    'y': '37.5221977912172'},
#   {'address_name': '서울 강남구 신사동 663-9',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 일식 > 돈까스,우동',
#    'distance': '',
#    'id': '10867025',
#    'phone': '02-514-5557',
#    'place_name': '압구정하루',
#    'place_url': 'http://place.map.kakao.com/10867025',
#    'road_address_name': '서울 강남구 언주로172길 56',
#    'x': '127.03829451168833',
#    'y': '37.526770520207805'}],
#  'meta': {'is_end': False,
#   'pageable_count': 45,
#   'same_name': {'keyword': '일식집', 'region': [], 'selected_region': '서울 강남구'},
#   'total_count': 2330}}

# %%
import json

context = ''
i = 1;
for place in places['documents']:
    context = context + f"{i}) {place['place_name']}, {place['address_name']}, {place['category_name']}"
    i = i + 1
context
# Out:
# '1) 카츠바이콘반, 서울 강남구 신사동 647-22, 음식점 > 일식 > 돈까스,우동2) 갓덴스시 강남점, 서울 강남구 역삼동 822-4, 음식점 > 일식 > 초밥,롤3) 정돈 강남점, 서울 강남구 역삼동 601-29, 음식점 > 일식 > 돈까스,우동4) 김수사, 서울 강남구 논현동 5-13, 음식점 > 일식 > 초밥,롤5) 현우동, 서울 강남구 논현동 11-1, 음식점 > 일식 > 돈까스,우동6) 정돈 신사점, 서울 강남구 신사동 519-4, 음식점 > 일식 > 돈까스,우동7) 큰물참치 강남점, 서울 강남구 역삼동 826-26, 음식점 > 일식 > 참치회8) 참치공방 강남점, 서울 강남구 역삼동 831-27, 음식점 > 일식 > 참치회9) 은행골 신사점, 서울 강남구 신사동 537-2, 음식점 > 일식 > 초밥,롤10) 가나돈까스의집, 서울 강남구 논현동 275-3, 음식점 > 일식 > 돈까스,우동11) 참치공방 선릉점, 서울 강남구 대치동 895-1, 음식점 > 일식12) 스시소라 대치점, 서울 강남구 대치동 894, 음식점 > 일식 > 초밥,롤13) 츄라우미 역삼본점, 서울 강남구 역삼동 677-5, 음식점 > 일식 > 초밥,롤14) 온기정, 서울 강남구 신사동 525-15, 음식점 > 일식15) 압구정하루, 서울 강남구 신사동 663-9, 음식점 > 일식 > 돈까스,우동'

# %%
import os
import openai
import json

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": f"주어진 문단을 보고 다음 질문에 답해줘: {question}"
    },
    {
      "role": "user",
      "content": context
    }
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 강남에 있는 일식집 중 추천할 만한 두세 곳은 다음과 같습니다:
#
# 1. **갓덴스시 강남점** - 초밥과 롤을 전문으로 하는 일식집입니다.
# 2. **큰물참치 강남점** - 신선한 참치회를 즐길 수 있는 곳입니다.
# 3. **정돈 강남점** - 돈까스와 우동을 제공하는 인기 있는 일식집입니다.
#
# 이 외에도 다양한 일식집이 있으니, 취향에 맞게 선택해 보세요!
